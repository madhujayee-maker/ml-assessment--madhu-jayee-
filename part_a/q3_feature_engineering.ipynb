# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor

# %%
df = pd.read_csv('../data/q3_retail_promotions.csv')
df.head()
# Out:
#   transaction_date  store_id store_size location_type  promotion_type  \
# 0       2022-01-01        28      small    semi-urban       free_gift
# 1       2022-01-01         5     medium    semi-urban       free_gift
# 2       2022-01-02        13      small    semi-urban  loyalty_points
# 3       2022-01-02        17      small         urban       free_gift
# 4       2022-01-03        50     medium    semi-urban            bogo
#
#    is_weekend  is_festival  competition_density  items_sold
# 0           1            0                    5         224
# 1           1            1                    1         348
# 2           1            0                    6         249
# 3           1            0                    7         259
# 4           0            0                    3         277

# %%
df['transaction_date'] = pd.to_datetime(df['transaction_date'])

df['year'] = df['transaction_date'].dt.year
df['month'] = df['transaction_date'].dt.month
df['day_of_week'] = df['transaction_date'].dt.dayofweek

df['is_month_end'] = (df['transaction_date'].dt.day >= 25).astype(int)

df.head()
# Out:
#   transaction_date  store_id store_size location_type  promotion_type  \
# 0       2022-01-01        28      small    semi-urban       free_gift
# 1       2022-01-01         5     medium    semi-urban       free_gift
# 2       2022-01-02        13      small    semi-urban  loyalty_points
# 3       2022-01-02        17      small         urban       free_gift
# 4       2022-01-03        50     medium    semi-urban            bogo
#
#    is_weekend  is_festival  competition_density  items_sold  year  month  \
# 0           1            0                    5         224  2022      1
# 1           1            1                    1         348  2022      1
# 2           1            0                    6         249  2022      1
# 3           1            0                    7         259  2022      1
# 4           0            0                    3         277  2022      1
#
#    day_of_week  is_month_end
# 0            5             0
# 1            5             0
# ...

# %%
df = df.sort_values('transaction_date')

split_index = int(len(df) * 0.8)

train = df[:split_index]
test = df[split_index:]

X_train = train.drop(['items_sold','transaction_date'], axis=1)
y_train = train['items_sold']

X_test = test.drop(['items_sold','transaction_date'], axis=1)
y_test = test['items_sold']

# %% [markdown]
# ### Why not random split?
# Random split breaks time dependency. Future data may leak into training, causing unrealistic performance. Time-based split ensures proper evaluation.

# %%
categorical_cols = ['promotion_type','location_type','store_size']
numerical_cols = [col for col in X_train.columns if col not in categorical_cols]

preprocessor = ColumnTransformer([
   ('num', StandardScaler(), numerical_cols),
   ('cat', OneHotEncoder(drop='first'), categorical_cols)
])

# %%
lr_pipeline = Pipeline([
   ('preprocessor', preprocessor),
   ('model', LinearRegression())
])

rf_pipeline = Pipeline([
   ('preprocessor', preprocessor),
   ('model', RandomForestRegressor(random_state=42))
])

lr_pipeline.fit(X_train, y_train)
rf_pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   ['store_id', 'is_weekend',
#                                                    'is_festival',
#                                                    'competition_density',
#                                                    'year', 'month',
#                                                    'day_of_week',
#                                                    'is_month_end']),
#                                                  ('cat',
#                                                   OneHotEncoder(drop='first'),
#                                                   ['promotion_type',
#                                                    'location_type',
#                                                    'store_size'])])),
#                 ('model', RandomForestRegressor(random_state=42))])

# %%
def evaluate(model, X_test, y_test):
   preds = model.predict(X_test)
   rmse = np.sqrt(mean_squared_error(y_test, preds))
   mae = mean_absolute_error(y_test, preds)
   print("RMSE:", rmse)
   print("MAE:", mae)
   return preds

print("Linear Regression")
lr_preds = evaluate(lr_pipeline, X_test, y_test)

print("\nRandom Forest")
rf_preds = evaluate(rf_pipeline, X_test, y_test)
# Out:
# Linear Regression
# RMSE: 27.121451164890622
# MAE: 21.052926674588388
#
# Random Forest
# RMSE: 31.715342449147013
# MAE: 25.136166666666668

# %%
plt.scatter(y_test, rf_preds)
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Parity Plot")
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--')
plt.show()

# %%
rf_model = rf_pipeline.named_steps['model']
importances = rf_model.feature_importances_

feature_names = (
   numerical_cols +
   list(rf_pipeline.named_steps['preprocessor']
        .named_transformers_['cat']
        .get_feature_names_out(categorical_cols))
)

feat_df = pd.DataFrame({
   'feature': feature_names,
   'importance': importances
}).sort_values(by='importance', ascending=False)

feat_df.head()
# Out:
#                 feature  importance
# 15     store_size_small    0.183639
# 2           is_festival    0.173564
# 13  location_type_urban    0.141218
# 6           day_of_week    0.090867
# 1            is_weekend    0.063608
